# %%
import pandas as pd

df = pd.read_csv('ddd.csv')
df.head()
# 네이버 테이블 분리
# naver_review = df.loc[:,['name', 'review']]
# df.drop(columns='review', inplace=True)
# Out:
#    Unnamed: 0    name                                                url  \
# 0           0    시민덕희  https://search.naver.com/search.naver?where=ne...
# 1           1  외계+인2부  https://search.naver.com/search.naver?where=ne...
# 2           2      위시  https://search.naver.com/search.naver?where=ne...
# 3           3     도그맨  https://search.naver.com/search.naver?where=ne...
# 4           4    서울의봄  https://search.naver.com/search.naver?where=ne...
#
#                                              img_url   people  rank  genre  \
# 0  https://search.pstatic.net/common?type=o&size=...     20만명  8.82    드라마
# 1  https://search.pstatic.net/common?type=o&size=...    120만명  8.27    로맨스
# 2  https://search.pstatic.net/common?type=o&size=...    127만명  7.25  애니메이션
# 3  https://search.pstatic.net/common?type=o&size=...    2.1만명  7.43    드라마
# 4  https://search.pstatic.net/common?type=o&size=...  1,299만명  9.53    드라마
#
#        country runtime
# 0     ['대한민국']    114분
# 1     ['대한민국']    122분
# ...

# %%
from pymongo import MongoClient
client = MongoClient('localhost', 27017)

# %%
db = client.movies.card

# %%
result = df.to_dict(orient='records')

# %%
db.insert_many(result)

# %%
list(db.find())
# Out:
# [{'_id': ObjectId('65b470de0ca865ecbd8b8333'),
#   'Unnamed: 0': 0,
#   'name': '시민덕희',
#   'url': 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=영화시민덕희',
#   'img_url': 'https://search.pstatic.net/common?type=o&size=176x264&quality=85&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20240124_126%2F1706084548964mScff_JPEG%2Fmovie_image.jpg%3Ftype%3Dw640_2',
#   'people': '20만명',
#   'rank': 8.82,
#   'genre': '드라마',
#   'country': "['대한민국']",
#   'runtime': '114분'},
#  {'_id': ObjectId('65b470de0ca865ecbd8b8334'),
#   'Unnamed: 0': 1,
#   'name': '외계+인2부',
#   'url': 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=영화외계+인2부',
#   'img_url': 'https://search.pstatic.net/common?type=o&size=176x264&quality=85&direct=true&src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20231215_228%2F1702622558194p8LNL_PNG%2Fmovie_image.jpg%3Ftype%3Dw640_2',
#   'people': '120만명',
#   'rank': 8.27,
#   'genre': '로맨스',
# ...

# %%
name_list = list(df.name.values)

for name in name_list:
    db.update_one({'name' : name}, {'$set' : {'like' : 0}})

# %%
# !pip install transformers
import torch
from model import process_news_keyword

df = pd.read_csv('review.csv')

result = process_news_keyword(df)
result
# Out:
# ...
#   Using cached transformers-4.18.0-py3-none-any.whl (4.0 MB)
# ...
#   Using cached regex-2023.8.8-cp36-cp36m-win_amd64.whl (280 kB)
# ...
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# ...
#   Using cached tokenizers-0.12.1.tar.gz (220 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Using cached sacremoses-0.0.53-py3-none-any.whl
# ...
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# ...
#   Using cached filelock-3.4.1-py3-none-any.whl (9.9 kB)
# ...
#   Using cached huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
# ...
#   Using cached PyYAML-6.0.1-cp36-cp36m-win_amd64.whl (153 kB)
# ...
#   Using cached joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# ...
# Failed to build tokenizers
#   ERROR: Command errored out with exit status 1:
# ...
